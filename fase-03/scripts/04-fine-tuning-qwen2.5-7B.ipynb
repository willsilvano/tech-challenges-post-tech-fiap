# %% [markdown]
# # Fine Tuning Qwen 2.5 7B
#
# Esse fine tuning tem como objetivo refinar o modelo LLM Qwen 2.5 7B para a tarefa de geração de descrição a partir do título de um produto.
#
# O dataset utilizado é uma amostra aleatória de 1000 produtos do dataset fornecido pela FIAP que contém produtos da Amazon.

# %% [markdown]
# Conectando o Google Drive para salvar o modelo treinado.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Instala as biblitecas necessárias para o fine tunning com Unsloth.

# %%
# %%capture
# !pip install unsloth
# !pip uninstall unsloth -y && pip install --upgrade --no-cache-dir --no-deps git+https://github.com/unslothai/unsloth.git

# %% [markdown]
# Carrega o dataset a ser utilizado para o fine tunning.
#
# Exibe a primeira linha.

# %%
from datasets import load_dataset

DRIVE_PATH = '/content/drive/MyDrive/FIAP/Qwen2.5'

dataset = load_dataset('csv', data_files=f"{DRIVE_PATH}/../data-1000.csv", split = "train")

dataset[0]
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# {'title': "Diver: A Royal Navy and Commercial Diver's Journey Through Life, and Around the World",
#  'content': "Anyone who has ever been affiliated with a military underwater demolition team or had the desire to enlist in one will not be able to put downDiverby Tony Groom. . . . Much of his first-person narrative is a candid look at adventures, relationships, personal triumphs and failures of a man whose job is to install or defuse explosives in cold dark waters. It demands nerves of steel, since one slight error would be the last error.(Northeast Dive News)Diveris the story of Tony Groom, a man who enlisted at the age of seventeen to become a diver for the Royal Navy. Serving countless years under extremely dangerous conditions, he speaks on his past career and his current career as a commercial diver.A tale of a man who truly loves what he does when no one else would think of doing it,Diveris an enthusiastically recommended tale.(Bookwatch2009-02-01)Wide-ranging, illuminating and sympathetic ... This tale fills a massive gap and is long overdue.(Commodore Michael C. Clapp)The Royal Navy Clearance Divers, not the SAS, are the British mystery unit of the Falklands War.(Major General Julian Thompson)Epitomises theesprit de corpsof the Royal Navy's Clearance Diving branch, as well as the close-knit camaraderie of the commercial offshore diver.(Mick Fellows)"}

# %% [markdown]
# Configura o modelo a ser utilizado.

# %%
from unsloth import FastLanguageModel
import torch

max_seq_length = 2048
dtype = None
load_in_4bit = True

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/Qwen2.5-7B",
    max_seq_length = max_seq_length,
    dtype = dtype,
    load_in_4bit = load_in_4bit,
)

model = FastLanguageModel.get_peft_model(
    model,
    r = 16,
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                      "gate_proj", "up_proj", "down_proj",],
    lora_alpha = 16,
    lora_dropout = 0,
    bias = "none",
    use_gradient_checkpointing = "unsloth",
    random_state = 3407,
    use_rslora = False,
    loftq_config = None,
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# ==((====))==  Unsloth 2025.3.9: Fast Qwen2 patching. Transformers: 4.48.3.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.6.0+cu124. CUDA: 7.5. CUDA Toolkit: 12.4. Triton: 3.2.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.29.post3. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors.index.json:   0%|          | 0.00/106k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/2.54G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/172 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/4.72k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/605 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/617 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]

# %% [markdown]
# Preparação do prompt para o fine tunning.

# %%
alpaca_prompt = """Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.

### Instruction:
Given a product title, generate a detailed and persuasive description highlighting its key features and benefits.

### Input:
{}

### Response:
{}"""

EOS_TOKEN = tokenizer.eos_token

def formatting_prompts_func(examples):
    inputs       = examples["title"]
    outputs      = examples["content"]
    texts = []
    for input, output in zip(inputs, outputs):
        text = alpaca_prompt.format(input, output) + EOS_TOKEN
        texts.append(text)
    return { "text" : texts, }

dataset = dataset.map(formatting_prompts_func, batched = True,)
# Out:
# Map:   0%|          | 0/1232 [00:00<?, ? examples/s]

# %% [markdown]
# Exibe a primeira linha para verificação

# %%
dataset[0]
# Out:
# {'title': "Diver: A Royal Navy and Commercial Diver's Journey Through Life, and Around the World",
#  'content': "Anyone who has ever been affiliated with a military underwater demolition team or had the desire to enlist in one will not be able to put downDiverby Tony Groom. . . . Much of his first-person narrative is a candid look at adventures, relationships, personal triumphs and failures of a man whose job is to install or defuse explosives in cold dark waters. It demands nerves of steel, since one slight error would be the last error.(Northeast Dive News)Diveris the story of Tony Groom, a man who enlisted at the age of seventeen to become a diver for the Royal Navy. Serving countless years under extremely dangerous conditions, he speaks on his past career and his current career as a commercial diver.A tale of a man who truly loves what he does when no one else would think of doing it,Diveris an enthusiastically recommended tale.(Bookwatch2009-02-01)Wide-ranging, illuminating and sympathetic ... This tale fills a massive gap and is long overdue.(Commodore Michael C. Clapp)The Royal Navy Clearance Divers, not the SAS, are the British mystery unit of the Falklands War.(Major General Julian Thompson)Epitomises theesprit de corpsof the Royal Navy's Clearance Diving branch, as well as the close-knit camaraderie of the commercial offshore diver.(Mick Fellows)",
#  'text': "Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.\n\n### Instruction:\nGiven a product title, generate a detailed and persuasive description highlighting its key features and benefits.\n\n### Input:\nDiver: A Royal Navy and Commercial Diver's Journey Through Life, and Around the World\n\n### Response:\nAnyone who has ever been affiliated with a military underwater demolition team or had the desire to enlist in one will not be able to put downDiverby Tony Groom. . . . Much of his first-person narrative is a candid look at adventures, relationships, personal triumphs and failures of a man whose job is to install or defuse explosives in cold dark waters. It demands nerves of steel, since one slight error would be the last error.(Northeast Dive News)Diveris the story of Tony Groom, a man who enlisted at the age of seventeen to become a diver for the Royal Navy. Serving countless years under extremely dangerous conditions, he speaks on his past career and his current career as a commercial diver.A tale of a man who truly loves what he does when no one else would think of doing it,Diveris an enthusiastically recommended tale.(Bookwatch2009-02-01)Wide-ranging, illuminating and sympathetic ... This tale fills a massive gap and is long overdue.(Commodore Michael C. Clapp)The Royal Navy Clearance Divers, not the SAS, are the British mystery unit of the Falklands War.(Major General Julian Thompson)Epitomises theesprit de corpsof the Royal Navy's Clearance Diving branch, as well as the close-knit camaraderie of the commercial offshore diver.(Mick Fellows)<|endoftext|>"}

# %% [markdown]
# Configura o treinamento do modelo.

# %%
from trl import SFTTrainer
from transformers import TrainingArguments
from unsloth import is_bfloat16_supported

trainer = SFTTrainer(
    model = model,
    tokenizer = tokenizer,
    train_dataset = dataset,
    dataset_text_field = "text",
    max_seq_length = max_seq_length,
    dataset_num_proc = 2,
    packing = False,
    args = TrainingArguments(
        per_device_train_batch_size = 2,
        gradient_accumulation_steps = 4,
        warmup_steps = 5,
        max_steps = 60,
        learning_rate = 2e-4,
        fp16 = not is_bfloat16_supported(),
        bf16 = is_bfloat16_supported(),
        logging_steps = 1,
        optim = "adamw_8bit",
        weight_decay = 0.01,
        lr_scheduler_type = "linear",
        seed = 3407,
        output_dir = "outputs",
        report_to = "none",
    ),
)
# Out:
# Tokenizing to ["text"] (num_proc=2):   0%|          | 0/1232 [00:00<?, ? examples/s]

# %% [markdown]
# Inicializa o treinamento.

# %%
trainer_stats = trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 1,232 | Num Epochs = 1 | Total steps = 60
# O^O/ \_/ \    Batch size per device = 2 | Gradient accumulation steps = 4
# \        /    Data Parallel GPUs = 1 | Total batch size (2 x 4 x 1) = 8
#  "-____-"     Trainable parameters = 40,370,176/5,063,120,384 (0.80% trained)
# Unsloth: Will smartly offload gradients to save VRAM!
#     <div>
#
#       <progress value='60' max='60' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [60/60 10:59, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.294100</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.146500</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.104600</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.028800</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.905200</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.923500</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.944300</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.609100</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.778400</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.598200</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.567700</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.319800</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>1.485800</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>1.178200</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>1.508600</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>1.212000</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>1.037100</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>1.395400</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>1.217800</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.613600</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>1.163700</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>1.060500</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>1.146300</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>1.253500</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>1.596200</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>1.442900</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>1.298600</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>1.355500</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>1.226300</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>1.167500</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>1.240200</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>1.401800</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>1.207800</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>1.385900</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>1.357300</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>1.621800</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>1.431800</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>1.200600</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>1.116700</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>1.378900</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>1.408000</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>1.392700</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>1.533300</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>1.222700</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.974700</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>1.371200</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>1.378600</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>1.439700</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>1.305200</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>1.141000</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>1.369300</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>1.270100</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>1.153400</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>1.121000</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>1.308900</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>1.590200</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>1.145600</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>1.177400</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>1.149200</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>1.258200</td>
#     </tr>
#   </tbody>
# </table><p>

# %% [markdown]
# Executa a inferência para gerar a descrição a partir do título.

# %%
FastLanguageModel.for_inference(model)

question = "CISCO C100"

inputs = tokenizer(
[
    alpaca_prompt.format(
        question,
        "",
    )
], return_tensors = "pt").to("cuda")

outputs = model.generate(**inputs, max_new_tokens = 64, use_cache = True)
tokenizer.batch_decode(outputs)
# Out:
# ['Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.\n\n### Instruction:\nGiven a product title, generate a detailed and persuasive description highlighting its key features and benefits.\n\n### Input:\nCISCO C100\n\n### Response:\nCISCO C100 is a 100% genuine Cisco C100 replacement. It is a high quality, low cost alternative to the original Cisco C100. It is a 100% compatible replacement for the original Cisco C100. It is a 10']

# %% [markdown]
# Salva o modelo treinado no Google Drive.

# %%
model.save_pretrained(f"{DRIVE_PATH}/lora_model-describe")
tokenizer.save_pretrained(f"{DRIVE_PATH}/lora_model-describe")
# Out:
# ('/content/drive/MyDrive/FIAP/FT-Qwen2.5/lora_model/tokenizer_config.json',
#  '/content/drive/MyDrive/FIAP/FT-Qwen2.5/lora_model/special_tokens_map.json',
#  '/content/drive/MyDrive/FIAP/FT-Qwen2.5/lora_model/vocab.json',
#  '/content/drive/MyDrive/FIAP/FT-Qwen2.5/lora_model/merges.txt',
#  '/content/drive/MyDrive/FIAP/FT-Qwen2.5/lora_model/added_tokens.json',
#  '/content/drive/MyDrive/FIAP/FT-Qwen2.5/lora_model/tokenizer.json')

# %% [markdown]
# Salva o modelo quantizado em 4Q no Google Drive.
#
# A partir do arquivo GGUF será possível carregar através de Ollama ou LMStudio em ambiente local.

# %%
model.save_pretrained_gguf(f"{DRIVE_PATH}/model", tokenizer, quantization_method = "q4_k_m")
# Out:
# Unsloth: You have 1 CPUs. Using `safe_serialization` is 10x slower.
# We shall switch to Pytorch saving, which might take 3 minutes and not 30 minutes.
# To force `safe_serialization`, set it to `None` instead.
# Unsloth: Kaggle/Colab has limited disk space. We need to delete the downloaded
# model which will save 4-16GB of disk space, allowing you to save on Kaggle/Colab.
# Unsloth: Will remove a cached repo with size 7.5G
# Unsloth: Merging 4bit and LoRA weights to 16bit...
# Unsloth: Will use up to 3.92 out of 12.67 RAM for saving.
# Unsloth: Saving model... This might take 5 minutes ...
#  36%|███▌      | 10/28 [00:00<00:01, 12.34it/s]
# We will save to Disk and not RAM now.
# 100%|██████████| 28/28 [02:25<00:00,  5.21s/it]
# Unsloth: Saving tokenizer... Done.
# Unsloth: Saving /content/drive/MyDrive/FIAP/FT-Qwen2.5/model/pytorch_model-00001-of-00004.bin...
# Unsloth: Saving /content/drive/MyDrive/FIAP/FT-Qwen2.5/model/pytorch_model-00002-of-00004.bin...
# Unsloth: Saving /content/drive/MyDrive/FIAP/FT-Qwen2.5/model/pytorch_model-00003-of-00004.bin...
# Unsloth: Saving /content/drive/MyDrive/FIAP/FT-Qwen2.5/model/pytorch_model-00004-of-00004.bin...
# Done.
# Unsloth: Converting qwen2 model. Can use fast conversion = False.
# ==((====))==  Unsloth: Conversion from QLoRA to GGUF information
#    \\   /|    [0] Installing llama.cpp might take 3 minutes.
# O^O/ \_/ \    [1] Converting HF to GGUF 16bits might take 3 minutes.
# \        /    [2] Converting GGUF 16bits to ['q8_0'] might take 10 minutes each.
#  "-____-"     In total, you will have to wait at least 16 minutes.
#
# Unsloth: Installing llama.cpp. This might take 3 minutes...
# Unsloth: CMAKE detected. Finalizing some steps for installation.
# Unsloth: [1] Converting model at /content/drive/MyDrive/FIAP/FT-Qwen2.5/model into q8_0 GGUF format.
# The output location will be /content/drive/MyDrive/FIAP/FT-Qwen2.5/model/unsloth.Q8_0.gguf
# This might take 3 minutes...
# INFO:hf-to-gguf:Loading model: model
# INFO:gguf.gguf_writer:gguf: This GGUF file is for Little Endian only
# INFO:hf-to-gguf:Exporting model...
# INFO:hf-to-gguf:gguf: loading model weight map from 'pytorch_model.bin.index.json'
# INFO:hf-to-gguf:gguf: loading model part 'pytorch_model-00001-of-00004.bin'
# INFO:hf-to-gguf:token_embd.weight,         torch.float16 --> Q8_0, shape = {3584, 152064}
# INFO:hf-to-gguf:blk.0.attn_q.bias,         torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.0.attn_q.weight,       torch.float16 --> Q8_0, shape = {3584, 3584}
# INFO:hf-to-gguf:blk.0.attn_k.bias,         torch.float16 --> F32, shape = {512}
# INFO:hf-to-gguf:blk.0.attn_k.weight,       torch.float16 --> Q8_0, shape = {3584, 512}
# INFO:hf-to-gguf:blk.0.attn_v.bias,         torch.float16 --> F32, shape = {512}
# INFO:hf-to-gguf:blk.0.attn_v.weight,       torch.float16 --> Q8_0, shape = {3584, 512}
# INFO:hf-to-gguf:blk.0.attn_output.weight,  torch.float16 --> Q8_0, shape = {3584, 3584}
# INFO:hf-to-gguf:blk.0.ffn_gate.weight,     torch.float16 --> Q8_0, shape = {3584, 18944}
# INFO:hf-to-gguf:blk.0.ffn_up.weight,       torch.float16 --> Q8_0, shape = {3584, 18944}
# INFO:hf-to-gguf:blk.0.ffn_down.weight,     torch.float16 --> Q8_0, shape = {18944, 3584}
# INFO:hf-to-gguf:blk.0.attn_norm.weight,    torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.0.ffn_norm.weight,     torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.1.attn_q.bias,         torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.1.attn_q.weight,       torch.float16 --> Q8_0, shape = {3584, 3584}
# INFO:hf-to-gguf:blk.1.attn_k.bias,         torch.float16 --> F32, shape = {512}
# INFO:hf-to-gguf:blk.1.attn_k.weight,       torch.float16 --> Q8_0, shape = {3584, 512}
# INFO:hf-to-gguf:blk.1.attn_v.bias,         torch.float16 --> F32, shape = {512}
# INFO:hf-to-gguf:blk.1.attn_v.weight,       torch.float16 --> Q8_0, shape = {3584, 512}
# INFO:hf-to-gguf:blk.1.attn_output.weight,  torch.float16 --> Q8_0, shape = {3584, 3584}
# INFO:hf-to-gguf:blk.1.ffn_gate.weight,     torch.float16 --> Q8_0, shape = {3584, 18944}
# INFO:hf-to-gguf:blk.1.ffn_up.weight,       torch.float16 --> Q8_0, shape = {3584, 18944}
# INFO:hf-to-gguf:blk.1.ffn_down.weight,     torch.float16 --> Q8_0, shape = {18944, 3584}
# INFO:hf-to-gguf:blk.1.attn_norm.weight,    torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.1.ffn_norm.weight,     torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.2.attn_q.bias,         torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.2.attn_q.weight,       torch.float16 --> Q8_0, shape = {3584, 3584}
# INFO:hf-to-gguf:blk.2.attn_k.bias,         torch.float16 --> F32, shape = {512}
# INFO:hf-to-gguf:blk.2.attn_k.weight,       torch.float16 --> Q8_0, shape = {3584, 512}
# INFO:hf-to-gguf:blk.2.attn_v.bias,         torch.float16 --> F32, shape = {512}
# INFO:hf-to-gguf:blk.2.attn_v.weight,       torch.float16 --> Q8_0, shape = {3584, 512}
# INFO:hf-to-gguf:blk.2.attn_output.weight,  torch.float16 --> Q8_0, shape = {3584, 3584}
# INFO:hf-to-gguf:blk.2.ffn_gate.weight,     torch.float16 --> Q8_0, shape = {3584, 18944}
# INFO:hf-to-gguf:blk.2.ffn_up.weight,       torch.float16 --> Q8_0, shape = {3584, 18944}
# INFO:hf-to-gguf:blk.2.ffn_down.weight,     torch.float16 --> Q8_0, shape = {18944, 3584}
# INFO:hf-to-gguf:blk.2.attn_norm.weight,    torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.2.ffn_norm.weight,     torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.3.attn_q.bias,         torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.3.attn_q.weight,       torch.float16 --> Q8_0, shape = {3584, 3584}
# INFO:hf-to-gguf:blk.3.attn_k.bias,         torch.float16 --> F32, shape = {512}
# INFO:hf-to-gguf:blk.3.attn_k.weight,       torch.float16 --> Q8_0, shape = {3584, 512}
# INFO:hf-to-gguf:blk.3.attn_v.bias,         torch.float16 --> F32, shape = {512}
# INFO:hf-to-gguf:blk.3.attn_v.weight,       torch.float16 --> Q8_0, shape = {3584, 512}
# INFO:hf-to-gguf:blk.3.attn_output.weight,  torch.float16 --> Q8_0, shape = {3584, 3584}
# INFO:hf-to-gguf:blk.3.ffn_gate.weight,     torch.float16 --> Q8_0, shape = {3584, 18944}
# INFO:hf-to-gguf:blk.3.ffn_up.weight,       torch.float16 --> Q8_0, shape = {3584, 18944}
# INFO:hf-to-gguf:blk.3.ffn_down.weight,     torch.float16 --> Q8_0, shape = {18944, 3584}
# INFO:hf-to-gguf:blk.3.attn_norm.weight,    torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.3.ffn_norm.weight,     torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.4.attn_q.bias,         torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.4.attn_q.weight,       torch.float16 --> Q8_0, shape = {3584, 3584}
# INFO:hf-to-gguf:blk.4.attn_k.bias,         torch.float16 --> F32, shape = {512}
# INFO:hf-to-gguf:blk.4.attn_k.weight,       torch.float16 --> Q8_0, shape = {3584, 512}
# INFO:hf-to-gguf:blk.4.attn_v.bias,         torch.float16 --> F32, shape = {512}
# INFO:hf-to-gguf:blk.4.attn_v.weight,       torch.float16 --> Q8_0, shape = {3584, 512}
# INFO:hf-to-gguf:blk.4.attn_output.weight,  torch.float16 --> Q8_0, shape = {3584, 3584}
# INFO:hf-to-gguf:blk.4.ffn_gate.weight,     torch.float16 --> Q8_0, shape = {3584, 18944}
# INFO:hf-to-gguf:blk.4.ffn_up.weight,       torch.float16 --> Q8_0, shape = {3584, 18944}
# INFO:hf-to-gguf:blk.4.ffn_down.weight,     torch.float16 --> Q8_0, shape = {18944, 3584}
# INFO:hf-to-gguf:blk.4.attn_norm.weight,    torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.4.ffn_norm.weight,     torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.5.attn_q.bias,         torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.5.attn_q.weight,       torch.float16 --> Q8_0, shape = {3584, 3584}
# INFO:hf-to-gguf:blk.5.attn_k.bias,         torch.float16 --> F32, shape = {512}
# INFO:hf-to-gguf:blk.5.attn_k.weight,       torch.float16 --> Q8_0, shape = {3584, 512}
# INFO:hf-to-gguf:blk.5.attn_v.bias,         torch.float16 --> F32, shape = {512}
# INFO:hf-to-gguf:blk.5.attn_v.weight,       torch.float16 --> Q8_0, shape = {3584, 512}
# INFO:hf-to-gguf:blk.5.attn_output.weight,  torch.float16 --> Q8_0, shape = {3584, 3584}
# INFO:hf-to-gguf:blk.5.ffn_gate.weight,     torch.float16 --> Q8_0, shape = {3584, 18944}
# INFO:hf-to-gguf:blk.5.ffn_up.weight,       torch.float16 --> Q8_0, shape = {3584, 18944}
# INFO:hf-to-gguf:blk.5.ffn_down.weight,     torch.float16 --> Q8_0, shape = {18944, 3584}
# INFO:hf-to-gguf:blk.5.attn_norm.weight,    torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.5.ffn_norm.weight,     torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.6.attn_q.bias,         torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.6.attn_q.weight,       torch.float16 --> Q8_0, shape = {3584, 3584}
# INFO:hf-to-gguf:blk.6.attn_k.bias,         torch.float16 --> F32, shape = {512}
# INFO:hf-to-gguf:blk.6.attn_k.weight,       torch.float16 --> Q8_0, shape = {3584, 512}
# INFO:hf-to-gguf:blk.6.attn_v.bias,         torch.float16 --> F32, shape = {512}
# INFO:hf-to-gguf:blk.6.attn_v.weight,       torch.float16 --> Q8_0, shape = {3584, 512}
# INFO:hf-to-gguf:blk.6.attn_output.weight,  torch.float16 --> Q8_0, shape = {3584, 3584}
# INFO:hf-to-gguf:blk.6.ffn_gate.weight,     torch.float16 --> Q8_0, shape = {3584, 18944}
# INFO:hf-to-gguf:blk.6.ffn_up.weight,       torch.float16 --> Q8_0, shape = {3584, 18944}
# INFO:hf-to-gguf:blk.6.ffn_down.weight,     torch.float16 --> Q8_0, shape = {18944, 3584}
# INFO:hf-to-gguf:blk.6.attn_norm.weight,    torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.6.ffn_norm.weight,     torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.7.attn_q.bias,         torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.7.attn_q.weight,       torch.float16 --> Q8_0, shape = {3584, 3584}
# INFO:hf-to-gguf:blk.7.attn_k.bias,         torch.float16 --> F32, shape = {512}
# INFO:hf-to-gguf:blk.7.attn_k.weight,       torch.float16 --> Q8_0, shape = {3584, 512}
# INFO:hf-to-gguf:blk.7.attn_v.bias,         torch.float16 --> F32, shape = {512}
# INFO:hf-to-gguf:blk.7.attn_v.weight,       torch.float16 --> Q8_0, shape = {3584, 512}
# INFO:hf-to-gguf:blk.7.attn_output.weight,  torch.float16 --> Q8_0, shape = {3584, 3584}
# INFO:hf-to-gguf:blk.7.ffn_gate.weight,     torch.float16 --> Q8_0, shape = {3584, 18944}
# INFO:hf-to-gguf:blk.7.ffn_up.weight,       torch.float16 --> Q8_0, shape = {3584, 18944}
# INFO:hf-to-gguf:blk.7.ffn_down.weight,     torch.float16 --> Q8_0, shape = {18944, 3584}
# INFO:hf-to-gguf:blk.7.attn_norm.weight,    torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.7.ffn_norm.weight,     torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.8.attn_q.bias,         torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.8.attn_q.weight,       torch.float16 --> Q8_0, shape = {3584, 3584}
# INFO:hf-to-gguf:blk.8.attn_k.bias,         torch.float16 --> F32, shape = {512}
# INFO:hf-to-gguf:blk.8.attn_k.weight,       torch.float16 --> Q8_0, shape = {3584, 512}
# INFO:hf-to-gguf:blk.8.attn_v.bias,         torch.float16 --> F32, shape = {512}
# INFO:hf-to-gguf:blk.8.attn_v.weight,       torch.float16 --> Q8_0, shape = {3584, 512}
# INFO:hf-to-gguf:blk.8.attn_output.weight,  torch.float16 --> Q8_0, shape = {3584, 3584}
# INFO:hf-to-gguf:gguf: loading model part 'pytorch_model-00002-of-00004.bin'
# INFO:hf-to-gguf:blk.8.ffn_gate.weight,     torch.float16 --> Q8_0, shape = {3584, 18944}
# INFO:hf-to-gguf:blk.8.ffn_up.weight,       torch.float16 --> Q8_0, shape = {3584, 18944}
# INFO:hf-to-gguf:blk.8.ffn_down.weight,     torch.float16 --> Q8_0, shape = {18944, 3584}
# INFO:hf-to-gguf:blk.8.attn_norm.weight,    torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.8.ffn_norm.weight,     torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.9.attn_q.bias,         torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.9.attn_q.weight,       torch.float16 --> Q8_0, shape = {3584, 3584}
# INFO:hf-to-gguf:blk.9.attn_k.bias,         torch.float16 --> F32, shape = {512}
# INFO:hf-to-gguf:blk.9.attn_k.weight,       torch.float16 --> Q8_0, shape = {3584, 512}
# INFO:hf-to-gguf:blk.9.attn_v.bias,         torch.float16 --> F32, shape = {512}
# INFO:hf-to-gguf:blk.9.attn_v.weight,       torch.float16 --> Q8_0, shape = {3584, 512}
# INFO:hf-to-gguf:blk.9.attn_output.weight,  torch.float16 --> Q8_0, shape = {3584, 3584}
# INFO:hf-to-gguf:blk.9.ffn_gate.weight,     torch.float16 --> Q8_0, shape = {3584, 18944}
# INFO:hf-to-gguf:blk.9.ffn_up.weight,       torch.float16 --> Q8_0, shape = {3584, 18944}
# INFO:hf-to-gguf:blk.9.ffn_down.weight,     torch.float16 --> Q8_0, shape = {18944, 3584}
# INFO:hf-to-gguf:blk.9.attn_norm.weight,    torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.9.ffn_norm.weight,     torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.10.attn_q.bias,        torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.10.attn_q.weight,      torch.float16 --> Q8_0, shape = {3584, 3584}
# INFO:hf-to-gguf:blk.10.attn_k.bias,        torch.float16 --> F32, shape = {512}
# INFO:hf-to-gguf:blk.10.attn_k.weight,      torch.float16 --> Q8_0, shape = {3584, 512}
# INFO:hf-to-gguf:blk.10.attn_v.bias,        torch.float16 --> F32, shape = {512}
# INFO:hf-to-gguf:blk.10.attn_v.weight,      torch.float16 --> Q8_0, shape = {3584, 512}
# INFO:hf-to-gguf:blk.10.attn_output.weight, torch.float16 --> Q8_0, shape = {3584, 3584}
# INFO:hf-to-gguf:blk.10.ffn_gate.weight,    torch.float16 --> Q8_0, shape = {3584, 18944}
# INFO:hf-to-gguf:blk.10.ffn_up.weight,      torch.float16 --> Q8_0, shape = {3584, 18944}
# INFO:hf-to-gguf:blk.10.ffn_down.weight,    torch.float16 --> Q8_0, shape = {18944, 3584}
# INFO:hf-to-gguf:blk.10.attn_norm.weight,   torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.10.ffn_norm.weight,    torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.11.attn_q.bias,        torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.11.attn_q.weight,      torch.float16 --> Q8_0, shape = {3584, 3584}
# INFO:hf-to-gguf:blk.11.attn_k.bias,        torch.float16 --> F32, shape = {512}
# INFO:hf-to-gguf:blk.11.attn_k.weight,      torch.float16 --> Q8_0, shape = {3584, 512}
# INFO:hf-to-gguf:blk.11.attn_v.bias,        torch.float16 --> F32, shape = {512}
# INFO:hf-to-gguf:blk.11.attn_v.weight,      torch.float16 --> Q8_0, shape = {3584, 512}
# INFO:hf-to-gguf:blk.11.attn_output.weight, torch.float16 --> Q8_0, shape = {3584, 3584}
# INFO:hf-to-gguf:blk.11.ffn_gate.weight,    torch.float16 --> Q8_0, shape = {3584, 18944}
# INFO:hf-to-gguf:blk.11.ffn_up.weight,      torch.float16 --> Q8_0, shape = {3584, 18944}
# INFO:hf-to-gguf:blk.11.ffn_down.weight,    torch.float16 --> Q8_0, shape = {18944, 3584}
# INFO:hf-to-gguf:blk.11.attn_norm.weight,   torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.11.ffn_norm.weight,    torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.12.attn_q.bias,        torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.12.attn_q.weight,      torch.float16 --> Q8_0, shape = {3584, 3584}
# INFO:hf-to-gguf:blk.12.attn_k.bias,        torch.float16 --> F32, shape = {512}
# INFO:hf-to-gguf:blk.12.attn_k.weight,      torch.float16 --> Q8_0, shape = {3584, 512}
# INFO:hf-to-gguf:blk.12.attn_v.bias,        torch.float16 --> F32, shape = {512}
# INFO:hf-to-gguf:blk.12.attn_v.weight,      torch.float16 --> Q8_0, shape = {3584, 512}
# INFO:hf-to-gguf:blk.12.attn_output.weight, torch.float16 --> Q8_0, shape = {3584, 3584}
# INFO:hf-to-gguf:blk.12.ffn_gate.weight,    torch.float16 --> Q8_0, shape = {3584, 18944}
# INFO:hf-to-gguf:blk.12.ffn_up.weight,      torch.float16 --> Q8_0, shape = {3584, 18944}
# INFO:hf-to-gguf:blk.12.ffn_down.weight,    torch.float16 --> Q8_0, shape = {18944, 3584}
# INFO:hf-to-gguf:blk.12.attn_norm.weight,   torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.12.ffn_norm.weight,    torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.13.attn_q.bias,        torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.13.attn_q.weight,      torch.float16 --> Q8_0, shape = {3584, 3584}
# INFO:hf-to-gguf:blk.13.attn_k.bias,        torch.float16 --> F32, shape = {512}
# INFO:hf-to-gguf:blk.13.attn_k.weight,      torch.float16 --> Q8_0, shape = {3584, 512}
# INFO:hf-to-gguf:blk.13.attn_v.bias,        torch.float16 --> F32, shape = {512}
# INFO:hf-to-gguf:blk.13.attn_v.weight,      torch.float16 --> Q8_0, shape = {3584, 512}
# INFO:hf-to-gguf:blk.13.attn_output.weight, torch.float16 --> Q8_0, shape = {3584, 3584}
# INFO:hf-to-gguf:blk.13.ffn_gate.weight,    torch.float16 --> Q8_0, shape = {3584, 18944}
# INFO:hf-to-gguf:blk.13.ffn_up.weight,      torch.float16 --> Q8_0, shape = {3584, 18944}
# INFO:hf-to-gguf:blk.13.ffn_down.weight,    torch.float16 --> Q8_0, shape = {18944, 3584}
# INFO:hf-to-gguf:blk.13.attn_norm.weight,   torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.13.ffn_norm.weight,    torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.14.attn_q.bias,        torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.14.attn_q.weight,      torch.float16 --> Q8_0, shape = {3584, 3584}
# INFO:hf-to-gguf:blk.14.attn_k.bias,        torch.float16 --> F32, shape = {512}
# INFO:hf-to-gguf:blk.14.attn_k.weight,      torch.float16 --> Q8_0, shape = {3584, 512}
# INFO:hf-to-gguf:blk.14.attn_v.bias,        torch.float16 --> F32, shape = {512}
# INFO:hf-to-gguf:blk.14.attn_v.weight,      torch.float16 --> Q8_0, shape = {3584, 512}
# INFO:hf-to-gguf:blk.14.attn_output.weight, torch.float16 --> Q8_0, shape = {3584, 3584}
# INFO:hf-to-gguf:blk.14.ffn_gate.weight,    torch.float16 --> Q8_0, shape = {3584, 18944}
# INFO:hf-to-gguf:blk.14.ffn_up.weight,      torch.float16 --> Q8_0, shape = {3584, 18944}
# INFO:hf-to-gguf:blk.14.ffn_down.weight,    torch.float16 --> Q8_0, shape = {18944, 3584}
# INFO:hf-to-gguf:blk.14.attn_norm.weight,   torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.14.ffn_norm.weight,    torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.15.attn_q.bias,        torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.15.attn_q.weight,      torch.float16 --> Q8_0, shape = {3584, 3584}
# INFO:hf-to-gguf:blk.15.attn_k.bias,        torch.float16 --> F32, shape = {512}
# INFO:hf-to-gguf:blk.15.attn_k.weight,      torch.float16 --> Q8_0, shape = {3584, 512}
# INFO:hf-to-gguf:blk.15.attn_v.bias,        torch.float16 --> F32, shape = {512}
# INFO:hf-to-gguf:blk.15.attn_v.weight,      torch.float16 --> Q8_0, shape = {3584, 512}
# INFO:hf-to-gguf:blk.15.attn_output.weight, torch.float16 --> Q8_0, shape = {3584, 3584}
# INFO:hf-to-gguf:blk.15.ffn_gate.weight,    torch.float16 --> Q8_0, shape = {3584, 18944}
# INFO:hf-to-gguf:blk.15.ffn_up.weight,      torch.float16 --> Q8_0, shape = {3584, 18944}
# INFO:hf-to-gguf:blk.15.ffn_down.weight,    torch.float16 --> Q8_0, shape = {18944, 3584}
# INFO:hf-to-gguf:blk.15.attn_norm.weight,   torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.15.ffn_norm.weight,    torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.16.attn_q.bias,        torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.16.attn_q.weight,      torch.float16 --> Q8_0, shape = {3584, 3584}
# INFO:hf-to-gguf:blk.16.attn_k.bias,        torch.float16 --> F32, shape = {512}
# INFO:hf-to-gguf:blk.16.attn_k.weight,      torch.float16 --> Q8_0, shape = {3584, 512}
# INFO:hf-to-gguf:blk.16.attn_v.bias,        torch.float16 --> F32, shape = {512}
# INFO:hf-to-gguf:blk.16.attn_v.weight,      torch.float16 --> Q8_0, shape = {3584, 512}
# INFO:hf-to-gguf:blk.16.attn_output.weight, torch.float16 --> Q8_0, shape = {3584, 3584}
# INFO:hf-to-gguf:blk.16.ffn_gate.weight,    torch.float16 --> Q8_0, shape = {3584, 18944}
# INFO:hf-to-gguf:blk.16.ffn_up.weight,      torch.float16 --> Q8_0, shape = {3584, 18944}
# INFO:hf-to-gguf:blk.16.ffn_down.weight,    torch.float16 --> Q8_0, shape = {18944, 3584}
# INFO:hf-to-gguf:blk.16.attn_norm.weight,   torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.16.ffn_norm.weight,    torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.17.attn_q.bias,        torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.17.attn_q.weight,      torch.float16 --> Q8_0, shape = {3584, 3584}
# INFO:hf-to-gguf:blk.17.attn_k.bias,        torch.float16 --> F32, shape = {512}
# INFO:hf-to-gguf:blk.17.attn_k.weight,      torch.float16 --> Q8_0, shape = {3584, 512}
# INFO:hf-to-gguf:blk.17.attn_v.bias,        torch.float16 --> F32, shape = {512}
# INFO:hf-to-gguf:blk.17.attn_v.weight,      torch.float16 --> Q8_0, shape = {3584, 512}
# INFO:hf-to-gguf:blk.17.attn_output.weight, torch.float16 --> Q8_0, shape = {3584, 3584}
# INFO:hf-to-gguf:blk.17.ffn_gate.weight,    torch.float16 --> Q8_0, shape = {3584, 18944}
# INFO:hf-to-gguf:blk.17.ffn_up.weight,      torch.float16 --> Q8_0, shape = {3584, 18944}
# INFO:hf-to-gguf:blk.17.ffn_down.weight,    torch.float16 --> Q8_0, shape = {18944, 3584}
# INFO:hf-to-gguf:blk.17.attn_norm.weight,   torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.17.ffn_norm.weight,    torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.18.attn_q.bias,        torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.18.attn_q.weight,      torch.float16 --> Q8_0, shape = {3584, 3584}
# INFO:hf-to-gguf:blk.18.attn_k.bias,        torch.float16 --> F32, shape = {512}
# INFO:hf-to-gguf:blk.18.attn_k.weight,      torch.float16 --> Q8_0, shape = {3584, 512}
# INFO:hf-to-gguf:blk.18.attn_v.bias,        torch.float16 --> F32, shape = {512}
# INFO:hf-to-gguf:blk.18.attn_v.weight,      torch.float16 --> Q8_0, shape = {3584, 512}
# INFO:hf-to-gguf:blk.18.attn_output.weight, torch.float16 --> Q8_0, shape = {3584, 3584}
# INFO:hf-to-gguf:blk.18.ffn_gate.weight,    torch.float16 --> Q8_0, shape = {3584, 18944}
# INFO:hf-to-gguf:blk.18.ffn_up.weight,      torch.float16 --> Q8_0, shape = {3584, 18944}
# INFO:hf-to-gguf:gguf: loading model part 'pytorch_model-00003-of-00004.bin'
# INFO:hf-to-gguf:blk.18.ffn_down.weight,    torch.float16 --> Q8_0, shape = {18944, 3584}
# INFO:hf-to-gguf:blk.18.attn_norm.weight,   torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.18.ffn_norm.weight,    torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.19.attn_q.bias,        torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.19.attn_q.weight,      torch.float16 --> Q8_0, shape = {3584, 3584}
# INFO:hf-to-gguf:blk.19.attn_k.bias,        torch.float16 --> F32, shape = {512}
# INFO:hf-to-gguf:blk.19.attn_k.weight,      torch.float16 --> Q8_0, shape = {3584, 512}
# INFO:hf-to-gguf:blk.19.attn_v.bias,        torch.float16 --> F32, shape = {512}
# INFO:hf-to-gguf:blk.19.attn_v.weight,      torch.float16 --> Q8_0, shape = {3584, 512}
# INFO:hf-to-gguf:blk.19.attn_output.weight, torch.float16 --> Q8_0, shape = {3584, 3584}
# INFO:hf-to-gguf:blk.19.ffn_gate.weight,    torch.float16 --> Q8_0, shape = {3584, 18944}
# INFO:hf-to-gguf:blk.19.ffn_up.weight,      torch.float16 --> Q8_0, shape = {3584, 18944}
# INFO:hf-to-gguf:blk.19.ffn_down.weight,    torch.float16 --> Q8_0, shape = {18944, 3584}
# INFO:hf-to-gguf:blk.19.attn_norm.weight,   torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.19.ffn_norm.weight,    torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.20.attn_q.bias,        torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.20.attn_q.weight,      torch.float16 --> Q8_0, shape = {3584, 3584}
# INFO:hf-to-gguf:blk.20.attn_k.bias,        torch.float16 --> F32, shape = {512}
# INFO:hf-to-gguf:blk.20.attn_k.weight,      torch.float16 --> Q8_0, shape = {3584, 512}
# INFO:hf-to-gguf:blk.20.attn_v.bias,        torch.float16 --> F32, shape = {512}
# INFO:hf-to-gguf:blk.20.attn_v.weight,      torch.float16 --> Q8_0, shape = {3584, 512}
# INFO:hf-to-gguf:blk.20.attn_output.weight, torch.float16 --> Q8_0, shape = {3584, 3584}
# INFO:hf-to-gguf:blk.20.ffn_gate.weight,    torch.float16 --> Q8_0, shape = {3584, 18944}
# INFO:hf-to-gguf:blk.20.ffn_up.weight,      torch.float16 --> Q8_0, shape = {3584, 18944}
# INFO:hf-to-gguf:blk.20.ffn_down.weight,    torch.float16 --> Q8_0, shape = {18944, 3584}
# INFO:hf-to-gguf:blk.20.attn_norm.weight,   torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.20.ffn_norm.weight,    torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.21.attn_q.bias,        torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.21.attn_q.weight,      torch.float16 --> Q8_0, shape = {3584, 3584}
# INFO:hf-to-gguf:blk.21.attn_k.bias,        torch.float16 --> F32, shape = {512}
# INFO:hf-to-gguf:blk.21.attn_k.weight,      torch.float16 --> Q8_0, shape = {3584, 512}
# INFO:hf-to-gguf:blk.21.attn_v.bias,        torch.float16 --> F32, shape = {512}
# INFO:hf-to-gguf:blk.21.attn_v.weight,      torch.float16 --> Q8_0, shape = {3584, 512}
# INFO:hf-to-gguf:blk.21.attn_output.weight, torch.float16 --> Q8_0, shape = {3584, 3584}
# INFO:hf-to-gguf:blk.21.ffn_gate.weight,    torch.float16 --> Q8_0, shape = {3584, 18944}
# INFO:hf-to-gguf:blk.21.ffn_up.weight,      torch.float16 --> Q8_0, shape = {3584, 18944}
# INFO:hf-to-gguf:blk.21.ffn_down.weight,    torch.float16 --> Q8_0, shape = {18944, 3584}
# INFO:hf-to-gguf:blk.21.attn_norm.weight,   torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.21.ffn_norm.weight,    torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.22.attn_q.bias,        torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.22.attn_q.weight,      torch.float16 --> Q8_0, shape = {3584, 3584}
# INFO:hf-to-gguf:blk.22.attn_k.bias,        torch.float16 --> F32, shape = {512}
# INFO:hf-to-gguf:blk.22.attn_k.weight,      torch.float16 --> Q8_0, shape = {3584, 512}
# INFO:hf-to-gguf:blk.22.attn_v.bias,        torch.float16 --> F32, shape = {512}
# INFO:hf-to-gguf:blk.22.attn_v.weight,      torch.float16 --> Q8_0, shape = {3584, 512}
# INFO:hf-to-gguf:blk.22.attn_output.weight, torch.float16 --> Q8_0, shape = {3584, 3584}
# INFO:hf-to-gguf:blk.22.ffn_gate.weight,    torch.float16 --> Q8_0, shape = {3584, 18944}
# INFO:hf-to-gguf:blk.22.ffn_up.weight,      torch.float16 --> Q8_0, shape = {3584, 18944}
# INFO:hf-to-gguf:blk.22.ffn_down.weight,    torch.float16 --> Q8_0, shape = {18944, 3584}
# INFO:hf-to-gguf:blk.22.attn_norm.weight,   torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.22.ffn_norm.weight,    torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.23.attn_q.bias,        torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.23.attn_q.weight,      torch.float16 --> Q8_0, shape = {3584, 3584}
# INFO:hf-to-gguf:blk.23.attn_k.bias,        torch.float16 --> F32, shape = {512}
# INFO:hf-to-gguf:blk.23.attn_k.weight,      torch.float16 --> Q8_0, shape = {3584, 512}
# INFO:hf-to-gguf:blk.23.attn_v.bias,        torch.float16 --> F32, shape = {512}
# INFO:hf-to-gguf:blk.23.attn_v.weight,      torch.float16 --> Q8_0, shape = {3584, 512}
# INFO:hf-to-gguf:blk.23.attn_output.weight, torch.float16 --> Q8_0, shape = {3584, 3584}
# INFO:hf-to-gguf:blk.23.ffn_gate.weight,    torch.float16 --> Q8_0, shape = {3584, 18944}
# INFO:hf-to-gguf:blk.23.ffn_up.weight,      torch.float16 --> Q8_0, shape = {3584, 18944}
# INFO:hf-to-gguf:blk.23.ffn_down.weight,    torch.float16 --> Q8_0, shape = {18944, 3584}
# INFO:hf-to-gguf:blk.23.attn_norm.weight,   torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.23.ffn_norm.weight,    torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.24.attn_q.bias,        torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.24.attn_q.weight,      torch.float16 --> Q8_0, shape = {3584, 3584}
# INFO:hf-to-gguf:blk.24.attn_k.bias,        torch.float16 --> F32, shape = {512}
# INFO:hf-to-gguf:blk.24.attn_k.weight,      torch.float16 --> Q8_0, shape = {3584, 512}
# INFO:hf-to-gguf:blk.24.attn_v.bias,        torch.float16 --> F32, shape = {512}
# INFO:hf-to-gguf:blk.24.attn_v.weight,      torch.float16 --> Q8_0, shape = {3584, 512}
# INFO:hf-to-gguf:blk.24.attn_output.weight, torch.float16 --> Q8_0, shape = {3584, 3584}
# INFO:hf-to-gguf:blk.24.ffn_gate.weight,    torch.float16 --> Q8_0, shape = {3584, 18944}
# INFO:hf-to-gguf:blk.24.ffn_up.weight,      torch.float16 --> Q8_0, shape = {3584, 18944}
# INFO:hf-to-gguf:blk.24.ffn_down.weight,    torch.float16 --> Q8_0, shape = {18944, 3584}
# INFO:hf-to-gguf:blk.24.attn_norm.weight,   torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.24.ffn_norm.weight,    torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.25.attn_q.bias,        torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.25.attn_q.weight,      torch.float16 --> Q8_0, shape = {3584, 3584}
# INFO:hf-to-gguf:blk.25.attn_k.bias,        torch.float16 --> F32, shape = {512}
# INFO:hf-to-gguf:blk.25.attn_k.weight,      torch.float16 --> Q8_0, shape = {3584, 512}
# INFO:hf-to-gguf:blk.25.attn_v.bias,        torch.float16 --> F32, shape = {512}
# INFO:hf-to-gguf:blk.25.attn_v.weight,      torch.float16 --> Q8_0, shape = {3584, 512}
# INFO:hf-to-gguf:blk.25.attn_output.weight, torch.float16 --> Q8_0, shape = {3584, 3584}
# INFO:hf-to-gguf:blk.25.ffn_gate.weight,    torch.float16 --> Q8_0, shape = {3584, 18944}
# INFO:hf-to-gguf:blk.25.ffn_up.weight,      torch.float16 --> Q8_0, shape = {3584, 18944}
# INFO:hf-to-gguf:blk.25.ffn_down.weight,    torch.float16 --> Q8_0, shape = {18944, 3584}
# INFO:hf-to-gguf:blk.25.attn_norm.weight,   torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.25.ffn_norm.weight,    torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.26.attn_q.bias,        torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.26.attn_q.weight,      torch.float16 --> Q8_0, shape = {3584, 3584}
# INFO:hf-to-gguf:blk.26.attn_k.bias,        torch.float16 --> F32, shape = {512}
# INFO:hf-to-gguf:blk.26.attn_k.weight,      torch.float16 --> Q8_0, shape = {3584, 512}
# INFO:hf-to-gguf:blk.26.attn_v.bias,        torch.float16 --> F32, shape = {512}
# INFO:hf-to-gguf:blk.26.attn_v.weight,      torch.float16 --> Q8_0, shape = {3584, 512}
# INFO:hf-to-gguf:blk.26.attn_output.weight, torch.float16 --> Q8_0, shape = {3584, 3584}
# INFO:hf-to-gguf:blk.26.ffn_gate.weight,    torch.float16 --> Q8_0, shape = {3584, 18944}
# INFO:hf-to-gguf:blk.26.ffn_up.weight,      torch.float16 --> Q8_0, shape = {3584, 18944}
# INFO:hf-to-gguf:blk.26.ffn_down.weight,    torch.float16 --> Q8_0, shape = {18944, 3584}
# INFO:hf-to-gguf:blk.26.attn_norm.weight,   torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.26.ffn_norm.weight,    torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.27.attn_q.bias,        torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.27.attn_q.weight,      torch.float16 --> Q8_0, shape = {3584, 3584}
# INFO:hf-to-gguf:blk.27.attn_k.bias,        torch.float16 --> F32, shape = {512}
# INFO:hf-to-gguf:blk.27.attn_k.weight,      torch.float16 --> Q8_0, shape = {3584, 512}
# INFO:hf-to-gguf:blk.27.attn_v.bias,        torch.float16 --> F32, shape = {512}
# INFO:hf-to-gguf:blk.27.attn_v.weight,      torch.float16 --> Q8_0, shape = {3584, 512}
# INFO:hf-to-gguf:blk.27.attn_output.weight, torch.float16 --> Q8_0, shape = {3584, 3584}
# INFO:hf-to-gguf:blk.27.ffn_gate.weight,    torch.float16 --> Q8_0, shape = {3584, 18944}
# INFO:hf-to-gguf:blk.27.ffn_up.weight,      torch.float16 --> Q8_0, shape = {3584, 18944}
# INFO:hf-to-gguf:blk.27.ffn_down.weight,    torch.float16 --> Q8_0, shape = {18944, 3584}
# INFO:hf-to-gguf:blk.27.attn_norm.weight,   torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:blk.27.ffn_norm.weight,    torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:output_norm.weight,        torch.float16 --> F32, shape = {3584}
# INFO:hf-to-gguf:gguf: loading model part 'pytorch_model-00004-of-00004.bin'
# INFO:hf-to-gguf:output.weight,             torch.float16 --> Q8_0, shape = {3584, 152064}
# INFO:hf-to-gguf:Set meta model
# INFO:hf-to-gguf:Set model parameters
# INFO:hf-to-gguf:gguf: context length = 131072
# INFO:hf-to-gguf:gguf: embedding length = 3584
# INFO:hf-to-gguf:gguf: feed forward length = 18944
# INFO:hf-to-gguf:gguf: head count = 28
# INFO:hf-to-gguf:gguf: key-value head count = 4
# INFO:hf-to-gguf:gguf: rope theta = 1000000.0
# INFO:hf-to-gguf:gguf: rms norm epsilon = 1e-06
# INFO:hf-to-gguf:gguf: file type = 7
# INFO:hf-to-gguf:Set model tokenizer
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# 2025-03-12 03:31:06.358886: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1741750266.616026   13741 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1741750266.686129   13741 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# INFO:gguf.vocab:Adding 151387 merge(s).
# INFO:gguf.vocab:Setting special token type eos to 151643
# INFO:gguf.vocab:Setting special token type pad to 151654
# INFO:gguf.vocab:Setting add_bos_token to False
# INFO:hf-to-gguf:Set model quantization version
# INFO:gguf.gguf_writer:Writing the following files:
# INFO:gguf.gguf_writer:/content/drive/MyDrive/FIAP/FT-Qwen2.5/model/unsloth.Q8_0.gguf: n_tensors = 339, total_size = 8.1G
# Writing: 100%|██████████| 8.09G/8.09G [04:00<00:00, 33.7Mbyte/s]
# INFO:hf-to-gguf:Model successfully exported to /content/drive/MyDrive/FIAP/FT-Qwen2.5/model/unsloth.Q8_0.gguf
# Unsloth: Conversion completed! Output location: /content/drive/MyDrive/FIAP/FT-Qwen2.5/model/unsloth.Q8_0.gguf
